# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
NewData=pd.read_excel("FinalDataSet_Cleaned.xlsx")
NewData

NewData = NewData.drop('Unnamed: 0', 1)
NewData
# Out:
#                     Name                                   AlternativeNames  \
# 0       Alpha Andromedae  Alpha Andromedae, Alf And, Sirrah, Sirah, Surr...
# 1        Beta Andromedae  Beta Andromedae, Bet And, HD 6860, TycId 2286-...
# 2       Delta Andromedae  Del And, HD 3627, TycId 2275-1753-1, HIP 3092,...
# 3          51 Andromedae  Upsilon Persei, HD 9927, TycId 3282-2271-1, HI...
# 4     Omicron Andromedae  Omicron Andromedae, Omi And, HD 217675, TycId ...
# ...                  ...                                                ...
# 3239        U Vulpeculae  HD 185059, TycId 1610-775-1, HIP 96458, BD+20 ...
# 3240           HD 190228           TycId 2153-1463-1, HIP 98714, BD+27 3593
# 3241           HD 189733  Wolf 864, TycId 2141-972-1, HIP 98505, BD +22 ...
# 3242           HD 188015           TycId 2148-1948-1, HIP 97769, BD+27 3539
# 3243           HD 203030          TycId 2190-1095-1, HIP 105232, BD+25 4507
#
#      SpectralType BinaryorMultipleStarSystem StarTypebasedonSpectralType  \
# 0             B9p                        Yes                        Star
# 1        M0IIIvar                        Yes                         NaN
# 2        K3III...                        Yes                         NaN
# 3           K3III                        NaN                         NaN
# 4         B6pv SB                        Yes                         NaN
# ...           ...                        ...                         ...
# 3239         F8IV                        NaN               Subgiant Star
# 3240         G5IV                        NaN               Subgiant Star
# 3241           G5                        NaN                        Star
# 3242         G5IV                        NaN               Subgiant Star
# 3243          G8V                        NaN          Main Sequence Star
#
#               Colour     Galaxy Constellation'sMainStar  \
# 0               Blue  Milky Way                     Yes
# 1                Red  Milky Way                     Yes
# 2      Orange to Red  Milky Way                     Yes
# 3      Orange to Red  Milky Way                     Yes
# 4               Blue  Milky Way                      No
# ...              ...        ...                     ...
# 3239  Yellow - White  Milky Way                      No
# 3240          Yellow  Milky Way                      No
# 3241          Yellow  Milky Way                      No
# 3242          Yellow  Milky Way                      No
# 3243          Yellow  Milky Way                      No
#
#                  NakedEyeVisible RightAscension  ...  \
# 0                            Yes  00h 08m 23.17  ...
# 1                            Yes  01h 09m 43.80  ...
# 2                            Yes  00h 39m 19.60  ...
# 3                            Yes  01h 37m 59.50  ...
# 4                            Yes  23h 01m 55.25  ...
# ...                          ...            ...  ...
# 3239  Requires a 7x50 Binoculars  19h 36m 37.73  ...
# 3240  Requires a 7x50 Binoculars  20h 03m 00.70  ...
# 3241  Requires a 7x50 Binoculars  20h 00m 43.71  ...
# 3242  Requires a 7x50 Binoculars  19h 52m 04.51  ...
# 3243  Requires a 7x50 Binoculars  21h 18m 58.13  ...
#
#      1997DistanceFromEarthInAU 2007DistanceFromEarthInLightYears  \
# 0                 6.138398e+06                             97.01
# 1                 1.260682e+07                            197.44
# 2                 6.408603e+06                            105.52
# 3                 1.099384e+07                            177.17
# 4                 4.379178e+07                            686.66
# ...                        ...                               ...
# 3239              3.495999e+08                           4868.11
# 3240              1.281102e+07                            200.96
# 3241              3.970570e+06                             63.44
# 3242              1.085564e+07                            185.95
# 3243              8.425859e+06                            133.35
#
#      2007DistanceFromEarthInParsecs  2007DistanceFromEarthInAU  \
# 0                             29.74               6.134273e+06
# 1                             60.53               1.248512e+07
# 2                             32.35               6.672620e+06
# 3                             54.32               1.120423e+07
# 4                            210.53               4.342463e+07
# ...                             ...                        ...
# 3239                        1492.54               3.078563e+08
# 3240                          61.61               1.270789e+07
# 3241                          19.45               4.011823e+06
# 3242                          57.01               1.175907e+07
# 3243                          40.88               8.432047e+06
#
#       GalactoCentricDistanceIn Parsecs  GalactoCentricDistanceInLightYears  \
# 0                               7409.0                            24165.44
# 1                               7433.0                            24243.72
# 2                               7414.0                            24181.75
# 3                               7435.0                            24250.24
# 4                               7445.0                            24282.86
# ...                                ...                                 ...
# 3239                               NaN                                 NaN
# 3240                            7375.0                            24054.55
# 3241                            7391.0                            24106.73
# 3242                            7376.0                            24057.81
# 3243                            7390.0                            24103.47
#
#       CommonName  ArabicNameTransliteration                Meaning  \
# 0      Alpheratz          (Surrat) al-Faras    (Navel of) the Mare
# 1         Mirach                 ʼal-Marāqq  the Loins/ Loinclotht
# 2            NaN                        NaN                    NaN
# 3            NaN                        NaN                    NaN
# 4            NaN                        NaN                    NaN
# ...          ...                        ...                    ...
# 3239         NaN                        NaN                    NaN
# 3240         NaN                        NaN                    NaN
# 3241         NaN                        NaN                    NaN
# 3242         NaN                        NaN                    NaN
# 3243         NaN                        NaN                    NaN
#
#         ArabicName
# 0     سُرَّة الفرس
# 1          المراقّ
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 3239           NaN
# 3240           NaN
# 3241           NaN
# 3242           NaN
# 3243           NaN
#
# [3244 rows x 42 columns]

# %%
NewData.describe()
# Out:
#           B-VIndex  ApparentMagnitude     Luminosity         Mass  \
# count  3243.000000        3243.000000    2844.000000  2567.000000
# mean      0.409914           5.387031     844.891382     5.068102
# std       4.662235           1.627258    4876.439067    56.018892
# min     -99.000000          -1.440000       0.010000     0.122100
# 25%       0.060000           4.480000      11.142500     1.300000
# 50%       0.580000           5.140000      65.915000     2.000000
# 75%       1.050000           6.090000     317.667500     3.510000
# max       4.410000          12.790000  125579.090000  2819.700000
#
#        SurfaceGravity  RadialVelocity  Rotational Velocity     Parallax  \
# count     2335.000000     3206.000000          2190.000000  3210.000000
# mean         4.632450        0.921797            65.239779    20.552588
# std         52.796488       27.609114            84.362634    37.275022
# min          0.000000     -171.120000             0.000000   -27.240000
# 25%          2.500000      -13.200000             3.700000     5.866375
# 50%          3.710000        0.300000            22.950000    10.940000
# 75%          4.150000       15.497500           107.000000    21.851350
# max       2489.000000      306.000000           500.000000   768.066500
#
#        EffectiveTemperature  AbsoluteMagnitude  ...  IronAbundance  \
# count           3162.000000        3227.000000  ...    1638.000000
# mean            7035.265971           0.552011  ...      -0.053101
# std             3239.333178           2.916143  ...       0.282366
# min                2.000000         -12.170000  ...      -3.500000
# 25%             4783.000000          -1.080000  ...      -0.150000
# 50%             5931.000000           0.400000  ...      -0.030000
# 75%             8815.000000           2.070000  ...       0.090000
# max            42775.000000          15.460000  ...       1.650000
#
#            Radius  1997DistanceFromEarthInLightYears  \
# count  2452.00000                        3190.000000
# mean     29.11990                         786.372655
# std      78.77065                        6376.548792
# min       0.01000                           0.000000
# 25%       1.98750                         146.917500
# 50%       5.09500                         294.110000
# 75%      20.66250                         546.340000
# max     972.00000                      326163.340000
#
#        1997DistanceFromEarthInParsecs  1997DistanceFromEarthInAU  \
# count                     3190.000000               3.190000e+03
# mean                       241.097912               4.972967e+07
# std                       1955.017009               4.032484e+08
# min                          0.000000               0.000000e+00
# 25%                         45.042500               9.290618e+06
# 50%                         90.170000               1.859877e+07
# 75%                        167.500000               3.454911e+07
# max                     100000.000000               2.062634e+10
#
#        2007DistanceFromEarthInLightYears  2007DistanceFromEarthInParsecs  \
# count                        3140.000000                     3140.000000
# mean                          881.955073                      270.402930
# std                          7526.314856                     2307.529356
# min                             4.090000                        1.250000
# 25%                           148.372500                       45.495000
# 50%                           296.915000                       91.030000
# 75%                           545.650000                      167.290000
# max                        326163.340000                   100000.000000
#
#        2007DistanceFromEarthInAU  GalactoCentricDistanceIn Parsecs  \
# count               3.140000e+03                       2968.000000
# mean                5.577422e+07                       7401.367588
# std                 4.759588e+08                         95.209906
# min                 2.578292e+05                       6666.000000
# 25%                 9.383952e+06                       7362.000000
# 50%                 1.877615e+07                       7397.000000
# 75%                 3.450580e+07                       7436.000000
# max                 2.062634e+10                       7930.000000
#
#        GalactoCentricDistanceInLightYears
# count                         2968.000000
# mean                         24140.548069
# std                            310.539844
# min                          21742.050000
# 25%                          24012.150000
# 50%                          24126.300000
# 75%                          24253.510000
# max                          25864.750000
#
# [8 rows x 23 columns]

# %%
plt.scatter(NewData['EffectiveTemperature'],NewData['SurfaceGravity'])
plt.xlabel('Eff. Temp')
plt.ylabel('Surface Gravity')
# Out:
# Text(0, 0.5, 'Surface Gravity')

# %%
fig = plt.figure(figsize=(8, 6))
plt.scatter(NewData['EffectiveTemperature'],NewData['ApparentMagnitude'])
plt.xlabel('Eff. Temp')
plt.ylabel('Apparent Magnitude')
# Out:
# Text(0, 0.5, 'Apparent Magnitude')

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot()
ax.text(2,-10,"Hyper Gaints",fontsize = 18)
ax.text(2,-6,"Super Giants",fontsize = 18)
ax.text(3,-4,"Bright Giants",fontsize = 18)
ax.text(2,-1,"Giants",fontsize = 18)
ax.text(5,1,"Sub Gaints",fontsize = 18)
ax.text(1,5,"Main Sequence(Dwarfs)",fontsize = 18)
ax.text(3,7.5,"Sub Dwarfs",fontsize = 18)
ax.text(2,12,"White Dwarfs",fontsize = 18)
ax.text(7,11,"Red Dwarfs",fontsize = 18)
ax.scatter(NewData['SpectralClass'],NewData['AbsoluteMagnitude'],c='g')
plt.xlabel('Spectral Class')
plt.ylabel('Absolute Magnitude')
ax.grid(axis = 'y')
ax.set_xticklabels(['O','B','A','F','G','K','M','L','T','Y'])
ax.invert_yaxis()
plt.show()
# Out:
# <ipython-input-15-372f302f0842>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['O','B','A','F','G','K','M','L','T','Y'])

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(NewData)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
my_report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
